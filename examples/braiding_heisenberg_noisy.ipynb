# %%
using Pkg
Pkg.develop("QuantumDots")
Pkg.activate(pwd())
Pkg.instantiate()
using QuantumDots, QuantumDots.BlockDiagonals, LinearAlgebra
using Plots
using DifferentialEquations
# Out:
#    Resolving package versions...
#   No Changes to `C:\Users\vi2823sv\.julia\dev\QuantumDots\examples\Project.toml`
#   No Changes to `C:\Users\vi2823sv\.julia\dev\QuantumDots\examples\Manifest.toml`
#   Activating project at `c:\Users\vi2823sv\.julia\dev\QuantumDots\examples`

# %%
struct MajoranaWrapper{B,D}
    basis::B
    majoranas::D
    function MajoranaWrapper(basis, labels=collect(Base.product(keys(basis), (:a, :b))))
        N = length(basis)
        length(labels) == 2 * N || throw(ErrorException("Number of majoranas is not twice the fermion number"))
        majA = map(f -> f + f', basis)
        majB = map(f -> 1im * (f - f'), basis)
        majs = vcat(majA, majB)
        dA = QuantumDots.dictionary(zip(labels[1:N], values(majA)))
        dB = QuantumDots.dictionary(zip(labels[N+1:2N], values(majB)))
        d = merge(dA, dB)
        new{typeof(basis),typeof(d)}(basis, d)
    end
end
Base.getindex(g::MajoranaWrapper, i...) = g.majoranas[i...]

# %%
c = FermionBasis(1:2)
γ = MajoranaWrapper(c, 0:3)
# Out:
# MajoranaWrapper{FermionBasis{2, Int64, SparseArrays.SparseMatrixCSC{Int64, Int64}, QuantumDots.NoSymmetry}, Dictionaries.Dictionary{Int64, SparseArrays.SparseMatrixCSC{T, Int64} where T}}(FermionBasis{2,Int64,SparseArrays.SparseMatrixCSC{Int64, Int64},QuantumDots.NoSymmetry}:
# keys = {1, 2}, {0 = sparse([2, 1, 4, 3], [1, 2, 3, 4], [1, 1, -1, -1], 4, 4), 1 = sparse([3, 4, 1, 2], [1, 2, 3, 4], [1, 1, 1, 1], 4, 4), 2 = sparse([2, 1, 4, 3], [1, 2, 3, 4], Complex{Int64}[0 - 1im, 0 + 1im, 0 + 1im, 0 - 1im], 4, 4), 3 = sparse([3, 4, 1, 2], [1, 2, 3, 4], Complex{Int64}[0 - 1im, 0 - 1im, 0 + 1im, 0 + 1im], 4, 4)})

# %%
smooth_step(x, k) = 1 / 2 + tanh(k * x) / 2
# Give the value of the three deltas at time t in the three point majorana braiding protocol
function braiding_deltas(t, T, Δmax, Δmin, k, args...)
    Δ1 = Δtrajectory(t, T, Δmax, Δmin, k)
    Δ2 = Δtrajectory(t + T / 3, T, Δmax, Δmin, k)
    Δ3 = Δtrajectory(t + 2T / 3, T, Δmax, Δmin, k)
    return Δ1, Δ2, Δ3
end
function Δtrajectory(t, T, Δmax, Δmin, k, args...)
    dΔ = Δmax - Δmin
    tp = mod(t, T) - T / 12
    Δmin + dΔ * smooth_step(tp - 1T / 6, k) - dΔ * smooth_step(tp - 4T / 6, k)
end
# Out:
# Δtrajectory (generic function with 1 method)

# %%
let T = 1, Δmax = 1, Δmin = 0.1, k = 30
    ts =  0:0.01:T
    deltas = stack([braiding_deltas(t, T, Δmax, Δmin, k) for t in ts])'
    plot(ts,deltas, label=["Δ1" "Δ2" "Δ3"], xlabel="t")
end

# %%
const γ01 = Matrix(1.0im * γ[0] * γ[1])
const γ02 = Matrix(1.0im * γ[0] * γ[2])
const γ03 = Matrix(1.0im * γ[0] * γ[3])
const γs = (γ01, γ02, γ03)
# Out:
# (ComplexF64[0.0 + 0.0im 0.0 + 0.0im 0.0 + 0.0im 0.0 + 1.0im; 0.0 + 0.0im 0.0 + 0.0im 0.0 + 1.0im 0.0 + 0.0im; 0.0 + 0.0im -0.0 - 1.0im 0.0 + 0.0im 0.0 + 0.0im; -0.0 - 1.0im 0.0 + 0.0im 0.0 + 0.0im 0.0 + 0.0im], ComplexF64[1.0 + 0.0im 0.0 + 0.0im 0.0 + 0.0im 0.0 + 0.0im; 0.0 + 0.0im -1.0 + 0.0im 0.0 + 0.0im 0.0 + 0.0im; 0.0 + 0.0im 0.0 + 0.0im 1.0 + 0.0im 0.0 + 0.0im; 0.0 + 0.0im 0.0 + 0.0im 0.0 + 0.0im -1.0 + 0.0im], ComplexF64[0.0 + 0.0im 0.0 + 0.0im 0.0 + 0.0im -1.0 + 0.0im; 0.0 + 0.0im 0.0 + 0.0im -1.0 + 0.0im 0.0 + 0.0im; 0.0 + 0.0im -1.0 + 0.0im 0.0 + 0.0im 0.0 + 0.0im; -1.0 + 0.0im 0.0 + 0.0im 0.0 + 0.0im 0.0 + 0.0im])

# %%
# function H((T, Δmin, Δmax, k), t)
#     Δs = braiding_deltas(t, T, Δmax, Δmin, k)
#     _H(Δs)
#     # Δ1, Δ2, Δ3 = Δs
#     # @. Δ1 * γ01 + Δ2 * γ02 + Δ3 * γ03
# end
function H((T, Δmin, Δmax, k), t, W)
    Δs = braiding_deltas(t, T, Δmax, Δmin, k)
    _H(W .+ Δs)
end
_H(Δs, γs=γs; cache=zero(first(γs))) = foldl((H, (γ, Δ)) -> H .+= Δ .* γ, zip(γs, Δs), init=cache)
# Out:
# _H (generic function with 2 methods)

# %%
function heisenberg!(du, u, p, t, W=0)#, p, t, args...)
    ham = H(p, t, W)#p, t, args...)
    mul!(du, ham, u, 1im, 0)
    mul!(du, u, ham, -1im, 1)
    return du
end
# Out:
# heisenberg! (generic function with 2 methods)

# %%
u0 = 1.0complex(Matrix(γ[1])) # Operator which will be time-evolved
T = 0.1
k = 100 / T
Δmax = 1e2 / T
Δmin = Δmax * 1e-2
σ = Δmax/10
p = (T, Δmin, Δmax, k)
tspan = (0.0, 2T)

prob = ODEProblem(heisenberg!, u0, tspan, p)
W = OrnsteinUhlenbeckProcess(1/(T), 0.0, σ, 0.0, zeros(3), zeros(3))
rodeprob = RODEProblem(heisenberg!, u0, tspan, p, noise=W, rand_prototype=zeros(Float64, 3), )
ts = range(0, tspan[2], 300)
deltas = stack([braiding_deltas(t, p...) for t in ts])'
plot(ts, deltas);

# %%
@time sol = solve(prob, saveat=ts)
@time rodesol = solve(rodeprob, saveat=ts, dt = T/100000, abstol=1e-3, reltol=1e-8)
# Out:
#  17.760723 seconds (25.52 M allocations: 1.635 GiB, 2.63% gc time, 99.95% compilation time)
#   6.829574 seconds (20.80 M allocations: 1.237 GiB, 10.22% gc time, 88.13% compilation time)
# retcode: Success
# Interpolation: 1st order linear
# t: 300-element Vector{Float64}:
#  0.0
#  0.0006688963210702341
#  0.0013377926421404682
#  0.002006688963210702
#  0.0026755852842809363
#  0.0033444816053511705
#  0.004013377926421404
#  0.0046822742474916385
#  0.005351170568561873
#  0.006020066889632107
#  ⋮
#  0.19464882943143813
#  0.19531772575250836
#  0.1959866220735786
#  0.19665551839464884
#  0.19732441471571907
#  0.1979933110367893
#  0.19866220735785953
#  0.19933110367892976
#  0.2
# u: 300-element Vector{Matrix{ComplexF64}}:
#  [0.0 + 0.0im 0.0 + 0.0im 1.0 + 0.0im 0.0 + 0.0im; 0.0 + 0.0im 0.0 + 0.0im 0.0 + 0.0im 1.0 + 0.0im; 1.0 + 0.0im 0.0 + 0.0im 0.0 + 0.0im 0.0 + 0.0im; 0.0 + 0.0im 1.0 + 0.0im 0.0 + 0.0im 0.0 + 0.0im]
#  [0.0 + 0.0im -0
 0.0 + 0.0im]
#  [0.0 + 0.0im 0.2001778396257865 - 0.17770185848098724im -0.9790185449212768 - 0.07430725065439861im 0.0 + 0.0im; 0.2001778396257865 + 0.17770185848098724im 0.0 + 0.0im 0.0 + 0.0im -0.9790185449212793 - 0.07430725065440391im; -0.9790185449212768 + 0.07430725065439861im 0.0 + 0.0im 0.0 + 0.0im -0.20017783962578564 + 0.17770185848099446im; 0.0 + 0.0im -0.9790185449212793 + 0.07430725065440391im -0.20017783962578564 - 0.17770185848099446im 0.0 + 0.0im]
#  [0.0 + 0.0im 0.11655041943734026 + 0.12396837161378298im -0.9769235129910301 + 0.22956557961273497im 0.0 + 0.0im; 0.11655041943734026 - 0.12396837161378298im 0.0 + 0.0im 0.0 + 0.0im -0.9769235129910251 + 0.22956557961272966im; -0.9769235129910301 - 0.22956557961273497im 0.0 + 0.0im 0.0 + 0.0im -0.11655041943734594 - 0.12396837161378264im; 0.0 + 0.0im -0.9769235129910251 - 0.22956557961272966im -0.11655041943734594 + 0.12396837161378264im 0.0 + 0.0im]
#  [0.0 + 0.0im -0.2703683051104345 - 0.02076784730425606im -0.9776900498318158 + 0.08372874913614388im 0.0 + 0.0im; -0.2703683051104345 + 0.02076784730425606im 0.0 + 0.0im 0.0 + 0.0im -0.9776900498318175 + 0.08372874913613865im; -0.9776900498318158 - 0.08372874913614388im 0.0 + 0.0im 0.0 + 0.0im 0.27036830511043525 + 0.020767847304248202im; 0.0 + 0.0im -0.9776900498318175 - 0.08372874913613865im 0.27036830511043525 - 0.020767847304248202im 0.0 + 0.0im]
#  [0.0 + 0.0im 0.03802695991077268 - 0.2402573894228191im -0.9791735421333116 - 0.1373123264430976im 0.0 + 0.0im; 0.03802695991077268 + 0.2402573894228191im 0.0 + 0.0im 0.0 + 0.0im -0.9791735421333175 - 0.13731232644310284im; -0.9791735421333116 + 0.1373123264430976im 0.0 + 0.0im 0.0 + 0.0im -0.038026959910768154 + 0.24025738942282396im; 0.0 + 0.0im -0.9791735421333175 + 0.13731232644310284im -0.038026959910768154 - 0.24025738942282396im 0.0 + 0.0im]
#  [0.0 + 0.0im 0.2508536242981423 + 0.031206623571895648im -0.9771176296314887 + 0.13614111377659288im 0.0 + 0.0im; 0.2508536242981423 - 0.031206623571895648im 0.0 + 0.0im 0.0 + 0.0im -0.9771176296314854 + 0.1361411137765876im; -0.9771176296314887 - 0.13614111377659288im 0.0 + 0.0im 0.0 + 0.0im -0.25085362429814795 - 0.031206623571889483im; 0.0 + 0.0im -0.9771176296314854 - 0.1361411137765876im -0.25085362429814795 + 0.031206623571889483im 0.0 + 0.0im]

# %%
γ_projections(sol::AbstractMatrix) = [abs(tr(γ * sol)) for γ in (γ[1], γ[2], γ[3])]
γ_projections(sol, ts::AbstractVector = ts) = transpose(reduce(hcat, map(t->γ_projections(sol(t)), ts)))
# Out:
# γ_projections (generic function with 3 methods)

# %%
projs = γ_projections(sol)
rodeprojs = γ_projections(rodesol);

# %%
plot(plot(ts ./ T, projs), plot(ts ./ T, rodeprojs))

# %%
plot(map(norm, sol))
plot!(map(norm, rodesol))

# %%
plot(stack(rodesol.W.u)'[1:100:end,:])

# %%
function prob_func(prob, i, repeat)
    W = OrnsteinUhlenbeckProcess(1/(T), 0.0, Δmax/10, 0.0, zeros(3), zeros(3))
    remake(prob; noise=W)
end
ensembleprob = EnsembleProblem(rodeprob;
    prob_func,
    output_func=(sol, i) -> ((map(s -> push!(γ_projections(s), norm(s)), sol)), false))
# Out:
# EnsembleProblem with problem RODEProblem

# %%
enssol = solve(ensembleprob, EnsembleThreads(), #ImplicitEulerHeun(symplectic=true, theta=1 / 2, autodiff=false),
    trajectories=50, saveat=ts, abstol=1e-6, reltol=1e-8, dt = T/100000)
# Out:
# EnsembleSolution Solution of length 50 with uType:
# Vector{Vector{Float64}}

# %%
using DifferentialEquations.EnsembleAnalysis
mv = [timestep_meanvar(enssol, n) for n in 1:size(enssol, 1)];
v = stack(last.(mv))'
m = stack(first.(mv))'
plot(ts, m; ribbon = (sqrt.(v),sqrt.(v)))
# Out:
# type Array has no field u
#
#
#
# Stacktrace:
#
#   [1] getproperty
#
#     @ .\Base.jl:37 [inlined]
#
#   [2] (::SciMLBase.EnsembleAnalysis.var"#1#2"{Int64})(sol::Vector{Vector{Float64}})
#
#     @ SciMLBase.EnsembleAnalysis .\none:0
#
#   [3] iterate
#
#     @ .\generator.jl:47 [inlined]
#
#   [4] first(itr::Base.Generator{EnsembleSolution{Vector{Float64}, 2, Vector{Vector{Vector{Float64}}}}, SciMLBase.EnsembleAnalysis.var"#1#2"{Int64}})
#
#     @ Base .\abstractarray.jl:472
#
#   [5] componentwise_meanvar(A::Base.Generator{EnsembleSolution{Vector{Float64}, 2, Vector{Vector{Vector{Float64}}}}, SciMLBase.EnsembleAnalysis.var"#1#2"{Int64}}; bessel::Bool)
#
#     @ SciMLBase.EnsembleAnalysis C:\Users\vi2823sv\.julia\packages\SciMLBase\hSv8d\src\ensemble\ensemble_analysis.jl:219
#
#   [6] componentwise_meanvar(A::Base.Generator{EnsembleSolution{Vector{Float64}, 2, Vector{Vector{Vector{Float64}}}}, SciMLBase.EnsembleAnalysis.var"#1#2"{Int64}})
#
#     @ SciMLBase.EnsembleAnalysis C:\Users\vi2823sv\.julia\packages\SciMLBase\hSv8d\src\ensemble\ensemble_analysis.jl:218
#
#   [7] timestep_meanvar(sim::EnsembleSolution{Vector{Float64}, 2, Vector{Vector{Vector{Float64}}}}, i::Int64)
#
#     @ SciMLBase.EnsembleAnalysis C:\Users\vi2823sv\.julia\packages\SciMLBase\hSv8d\src\ensemble\ensemble_analysis.jl:46
#
#   [8] (::var"#30#31")(n::Int64)
#
#     @ Main .\none:0
#
#   [9] iterate
#
#     @ .\generator.jl:47 [inlined]
#
#  [10] collect(itr::Base.Generator{UnitRange{Int64}, var"#30#31"})
#
#     @ Base .\array.jl:834
#
#  [11] top-level scope
#
#     @ c:\Users\vi2823sv\.julia\dev\QuantumDots\examples\braiding_heisenberg_noisy.ipynb:1
